# %%
#Importing the libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Peek into the data by creating pandas dataframe
star_df= pd.read_csv('https://drive.google.com/uc?id=1BQVc6MHjQFtDC9iP1isT_K4ojVe_Oil-')
#star_df.head()#default if gives 5 rows but we can custimize it
star_df.sample(10)#sample random values give it to us
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 194             3523          0.005400        0.3190                   12.43
# 126             2935          0.000870        0.0932                   16.88
# 152            14060       1092.000000        5.7450                   -2.04
# 235            38940     374830.000000     1356.0000                   -9.93
# 90              5300          0.590000        0.9100                    5.49
# 55              3450     263000.000000     1349.0000                  -11.75
# 165             7282     131000.000000       24.0000                   -7.22
# 189             3523          0.000957        0.1290                   16.35
# 185             2889          0.000352        0.0973                   16.93
# 45              3600     320000.000000       29.0000                   -6.60
#
#      Star type    Star color Spectral Class
# 194          1           Red              M
# ...

# %%
#check general information about the dataframe
star_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.3+ KB

# %%
#create a directory to save the visualization
folder_name='star_plots'
os.makedirs('star_plots',exist_ok=True)
base_dir =f'/content/star_plots/'

#bar chart to visualize the count of stars with respective type
star_df['Star type'].value_counts().plot(kind='line')
plt.show()

# %%
#Custimize the plot
plt.figure(figsize=(4,4))#for size
plt.style.use('default')#for changing the background
ax=star_df['Star type'].value_counts().plot(kind='bar',color=['red','blue','yellow','violet','orange','black'])
ax.bar_label(ax.containers[0],color='green')
plt.title("Visualize star count per star type",color='black',weight='bold')
plt.yticks(color='tab:red')
plt.ylabel('# of stars',color='cyan',fontsize='11')
plt.xticks(ticks=[0, 1, 2, 3, 4, 5],
           labels=['Brown\nDwarf', 'Red\nDwarf', 'White\nDwarf', 'Main\nSequence', 'Super\ngiants', 'Hyper\ngiants'],rotation=45,color='lime')
plt.savefig(base_dir +'barplot_star_count.png')
plt.show()

# %%
#practicing with different domains
folder_name='star_plot_temp'
os.makedirs('star_plot_temp',exist_ok= True)
base_dir=f'/content/star_plot_temp/'

axx=star_df['Spectral Class'].value_counts().plot(kind='line',color=['red','blue','green','cyan','pink','orange','violet'])
plt.title("Graph of Spectral class",color='red',weight='bold')
plt.ylabel('no.of stars',color='brown')
plt.xticks(rotation=10)
plt.savefig(base_dir +'barplot_star_spectral.png')
plt.show()

# %%
#Visulaising the star color data
folder_name='star_plot_temp'
os.makedirs('star_plot_temp',exist_ok= True)
base_dir=f'/content/star_plot_temp/'
ax= sns.lineplot(x=star_df['Star color'].value_counts().index ,y=star_df['Star color'].value_counts(),palette='viridis')
plt.title("visiualizing the count of star color",color='royalblue')
plt.xticks(rotation=45,color='blue')
plt.ylabel('Star Color',color='black')
plt.yticks(color='tab:blue')
plt.savefig(base_dir+'star_colors_viz.png')
plt.show()
# Out:
# <ipython-input-23-0639b7428c6a>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax= sns.lineplot(x=star_df['Star color'].value_counts().index ,y=star_df['Star color'].value_counts(),palette='viridis')

# %%
"""
manualy:
plt.subplot(1,4,1)
sns.boxplot(x=star_df['Star type'],y=star_df.iloc[:,0])#iloc[:,column no.]
plt.subplot(1,4,2)
sns.boxplot(x=star_df['Star type'],y=star_df.iloc[:,1])#iloc[:,column no.]
plt.subplot(1,4,3)
sns.boxplot(x=star_df['Star type'],y=star_df.iloc[:,2])#iloc[:,column no.]
"""
folder_name='star_plot_temp'
os.makedirs('star_plot_temp',exist_ok= True)
base_dir=f'/content/star_plot_temp/'
plt.figure(figsize=(25,9))
plt.style.use("default")
plt.suptitle('Visualiziting the outliers in numeric features of the star type')

#using forloop:
for i in range(4):
  plt.subplot(1,4,i+1)
  sns.lineplot(x=star_df['Star type'],y=star_df.iloc[:,i])
  plt.title(star_df.columns[i],color='red')
plt.savefig(base_dir+'lineplot_star_type.png')
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.suptitle('Visualizing The distribution of numeric features ',color='darkblue',fontsize=16,weight='bold')
colors=['red','grey','blue','orange']
for i in range(4):
  plt.subplot(4,1,i+1)
  plt.plot(star_df.iloc[:,i],color=colors[i])
  plt.title(star_df.columns[i],color='violet',weight='bold')

plt.savefig("graph1.png")
plt.show()

# %% [markdown]
# #Paitplot

# %%
#get a paitplot
sns.pairplot(star_df,hue='Spectral Class')
plt.savefig("pairplot")
plt.show()

# %% [markdown]
# #creating HR diagram

# %%
#Arrays to be used in the for loop
star_type = star_df['Star type'].values
temperature = star_df['Temperature (K)'].values
abs_mag = star_df['Absolute magnitude(Mv)'].values

# Python dictionaries --> Made of key value pairs --> To be used to get properties of star_type
star_types = {
    0: {'label': 'Brown Dwarf', 'color': 'brown', 'size': 30, 'marker': '.'},
    1: {'label': 'Red Dwarf', 'color': 'red', 'size': 35, 'marker': '.'},
    2: {'label': 'White Dwarf', 'color': 'white', 'size': 40, 'marker': '.'},
    3: {'label': 'Main Sequence', 'color': 'cyan', 'size': 30, 'marker': 'o'},
    4: {'label': 'Supergiants', 'color': 'orange', 'size': 100, 'marker': 'o'},
    5: {'label': 'Hypergiants', 'color': 'maroon', 'size': 150, 'marker': 'o'}
}

# %%
axes=[]
labels=set()

plt.style.use("dark_background")
for i in range(len(star_type)):
  properties=star_types[star_type[i]]
  if properties['label'] not in labels:
    ax=plt.scatter(temperature[i],abs_mag[i],s=properties['size'],c=properties['color'],marker=properties['marker'],
              label=properties['label'])
    axes.append(ax)
    labels.add(properties['label'])
  else:
    plt.scatter(temperature[i],abs_mag[i],s=properties['size'],c=properties['color'],marker=properties['marker'],
              label=properties['label'])

plt.legend(handles=axes)



plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
plt.savefig("HR diagram")
plt.show()
